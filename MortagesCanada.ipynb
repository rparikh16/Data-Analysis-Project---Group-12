# %%
import pandas as pd

# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf

#  Import and read the Data_Table_Mortages
import pandas as pd 
file_path = "/content/Data_Table_Mortgages.xlsx"
mortages_df=pd.read_excel(file_path)
mortages_df.head()
# Out:
#   Quarters  Mortgage_delinquency_rate  Average_Value_New_Loans  \
# 0   2013Q1                       0.37                   214203
# 1   2013Q2                       0.35                   212978
# 2   2013Q3                       0.35                   226172
# 3   2013Q4                       0.35                   223413
# 4   2014Q1                       0.37                   225005
#
#    Residential_Mortgage_Arrears_Rates
# 0                            0.320000
# 1                            0.310000
# 2                            0.311882
# 3                            0.315286
# 4                            0.305352

# %%
# Extract the year from the "Quarters" column
mortages_df['Year'] = mortages_df['Quarters'].str[:4].astype(int)

# %%
# Group the data by year and calculate the mean of each column
annual_data_Canada = mortages_df.groupby('Year').mean()

# %%
# Reset the index of the dataframe
annual_data_Canada = annual_data_Canada.reset_index()

# %%
annual_data_Canada.dtypes
# Out:
# Year                                    int64
# Mortgage_delinquency_rate             float64
# Average_Value_New_Loans               float64
# Residential_Mortgage_Arrears_Rates    float64
# dtype: object

# %%
annual_data_Canada.head()
# Out:
#    Year  Mortgage_delinquency_rate  Average_Value_New_Loans  \
# 0  2013                     0.3550                219191.50
# 1  2014                     0.3500                231196.75
# 2  2015                     0.3525                247453.25
# 3  2016                     0.3500                266337.50
# 4  2017                     0.3125                279651.75
#
#    Residential_Mortgage_Arrears_Rates
# 0                            0.314292
# 1                            0.290257
# 2                            0.274011
# 3                            0.279614
# 4                            0.248447

# %%
# Save the aggregated data back to the file
annual_data_Canada.to_excel("/content/Annual_Data.xlsx")

# %%
file_path_Ontario = "/content/Mortgages_Ontario.xlsx"
Ontario_df=pd.read_excel(file_path_Ontario)
Ontario_df.head()
# Out:
#   Quarters  Mortgage_delinquency_rate  Average_Value_New_Loans  \
# 0   2013Q1                       0.31                   233122
# 1   2013Q2                       0.29                   230770
# 2   2013Q3                       0.28                   249054
# 3   2013Q4                       0.28                   244060
# 4   2014Q1                       0.29                   244077
#
#    Residential_Mortgage_Arrears_Rates
# 0                            0.210000
# 1                            0.200000
# 2                            0.203259
# 3                            0.206203
# 4                            0.194819

# %%
# Extract the year from the "Quarters" column
Ontario_df['Year'] = Ontario_df['Quarters'].str[:4].astype(int)

# %%
# Group the data by year and calculate the mean of each column
Ontario_df = Ontario_df.groupby('Year').mean()

# %%
# Reset the index of the dataframe
Ontario_df = Ontario_df.reset_index()

# %%
Ontario_df.dtypes
# Out:
# Year                                    int64
# Mortgage_delinquency_rate             float64
# Average_Value_New_Loans               float64
# Residential_Mortgage_Arrears_Rates    float64
# dtype: object

# %%
Ontario_df.head()
# Out:
#    Year  Mortgage_delinquency_rate  Average_Value_New_Loans  \
# 0  2013                     0.2900                239251.50
# 1  2014                     0.2725                251246.75
# 2  2015                     0.2475                268252.00
# 3  2016                     0.2125                295313.75
# 4  2017                     0.1625                327009.00
#
#    Residential_Mortgage_Arrears_Rates
# 0                            0.204866
# 1                            0.181919
# 2                            0.153495
# 3                            0.133884
# 4                            0.104340

# %%
# Save the aggregated data back to the file
Ontario_df.to_excel("/content/Ontario_Data.xlsx")

# %%
file_path_Alberta = "//content/Mortages_Alberta.xlsx"
Alberta_df=pd.read_excel(file_path_Alberta)
Alberta_df.head()
# Out:
#   Quarters  Mortgage_delinquency_rate  Average_Value_New_Loans  \
# 0   2013Q1                       0.52                   277158
# 1   2013Q2                       0.47                   278516
# 2   2013Q3                       0.45                   289263
# 3   2013Q4                       0.43                   284928
# 4   2014Q1                       0.42                   291926
#
#    Residential_Mortgage_Arrears_Rates
# 0                            0.460000
# 1                            0.420000
# 2                            0.405950
# 3                            0.387605
# 4                            0.356118

# %%
# Extract the year from the "Quarters" column
Alberta_df['Year'] = Alberta_df['Quarters'].str[:4].astype(int)

# %%
# Group the data by year and calculate the mean of each column
Alberta_df = Alberta_df.groupby('Year').mean()

# %%
# Reset the index of the dataframe
Alberta_df = Alberta_df.reset_index()

# %%
Alberta_df.dtypes
# Out:
# Year                                    int64
# Mortgage_delinquency_rate             float64
# Average_Value_New_Loans               float64
# Residential_Mortgage_Arrears_Rates    float64
# dtype: object

# %%
Alberta_df.head()
# Out:
#    Year  Mortgage_delinquency_rate  Average_Value_New_Loans  \
# 0  2013                     0.4675                282466.25
# 1  2014                     0.3625                298145.00
# 2  2015                     0.3400                304252.50
# 3  2016                     0.4800                300443.25
# 4  2017                     0.5175                304217.00
#
#    Residential_Mortgage_Arrears_Rates
# 0                            0.418389
# 1                            0.306694
# 2                            0.274545
# 3                            0.407161
# 4                            0.442388

# %%
# Save the aggregated data back to the file
Alberta_df.to_excel("/content/Alberta_Data.xlsx")

# %%
file_path_BC = ("/content/Mortages_BC.xlsx")
BC_df=pd.read_excel(file_path_BC)
BC_df.head()
# Out:
#   Quarters  Mortgage_delinquency_rate  Average_Value_New_Loans  \
# 0   2013Q1                       0.43                   286652
# 1   2013Q2                       0.43                   290928
# 2   2013Q3                       0.42                   303663
# 3   2013Q4                       0.43                   305256
# 4   2014Q1                       0.43                   309374
#
#    Residential_Mortgage_Arrears_Rates
# 0                                0.45
# 1                                0.46
# 2                                0.47
# 3                                0.45
# 4                                0.44

# %%
# Extract the year from the "Quarters" column
BC_df['Year'] = BC_df['Quarters'].str[:4].astype(int)

# %%
# Group the data by year and calculate the mean of each column
BC_df = BC_df.groupby('Year').mean()

# %%
# Reset the index of the dataframe
BC_df = BC_df.reset_index()

# %%
BC_df.dtypes
# Out:
# Year                                    int64
# Mortgage_delinquency_rate             float64
# Average_Value_New_Loans               float64
# Residential_Mortgage_Arrears_Rates    float64
# dtype: object

# %%
BC_df.head()
# Out:
#    Year  Mortgage_delinquency_rate  Average_Value_New_Loans  \
# 0  2013                     0.4275                296624.75
# 1  2014                     0.4075                314877.50
# 2  2015                     0.3600                340315.75
# 3  2016                     0.2800                379173.00
# 4  2017                     0.1975                374620.50
#
#    Residential_Mortgage_Arrears_Rates
# 0                              0.4575
# 1                              0.3975
# 2                              0.3175
# 3                              0.2400
# 4                              0.1675

# %%
# Save the aggregated data back to the file
BC_df.to_excel("/content/BC_Data.xlsx")

# %%
file_path_Quebec = "/content/Mortages_Quebec.xlsx"
Quebec_df=pd.read_excel(file_path_Quebec)
Quebec_df.head()
# Out:
#   Quarters  Mortgage_delinquency_rate  Average_Value_New_Loans  \
# 0   2013Q1                       0.35                   153909
# 1   2013Q2                       0.34                   155016
# 2   2013Q3                       0.33                   160147
# 3   2013Q4                       0.35                   155512
# 4   2014Q1                       0.37                   156424
#
#    Residential_Mortgage_Arrears_Rates
# 0                            0.300000
# 1                            0.310000
# 2                            0.320017
# 3                            0.338168
# 4                            0.340243

# %%
# Extract the year from the "Quarters" column
Quebec_df['Year'] = Quebec_df['Quarters'].str[:4].astype(int)

# %%
# Group the data by year and calculate the mean of each column
Quebec_df = Quebec_df.groupby('Year').mean()

# %%
# Reset the index of the dataframe
Quebec_df = Quebec_df.reset_index()

# %%
Quebec_df.dtypes
# Out:
# Year                                    int64
# Mortgage_delinquency_rate             float64
# Average_Value_New_Loans               float64
# Residential_Mortgage_Arrears_Rates    float64
# dtype: object

# %%
Quebec_df.head()
# Out:
#    Year  Mortgage_delinquency_rate  Average_Value_New_Loans  \
# 0  2013                     0.3425                156146.00
# 1  2014                     0.3725                160772.00
# 2  2015                     0.4150                165241.25
# 3  2016                     0.4225                170827.75
# 4  2017                     0.3800                173549.00
#
#    Residential_Mortgage_Arrears_Rates
# 0                            0.317046
# 1                            0.344120
# 2                            0.360460
# 3                            0.356993
# 4                            0.307286

# %%
# Save the aggregated data back to the file
Quebec_df.to_excel("/content/Quebec_Data.xlsx")
